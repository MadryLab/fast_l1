# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
import sys
sys.path.append('../')
from fast_l1.logger import Reader

# %%
r = Reader('/mnt/nfs/home/ailyas/slurm/scratch/datamodel_big_logs_2/')

# %%
plt.plot(r.read_field(field_name='train_mse', index=1)[10:])
plt.plot(r.read_field(field_name='val_mse', index=1)[10:])
# Out:
# 3.0706313 None
# 738
# inf None
# 738

# %%
plt.plot(r.read_field(field_name='train_mse', index=1)[200:288])
# Out:
# 3.0676517 None
# 570

# %%
import numpy as np
print(np.where(~r.read_field(field_name='still_optimizing_outer', index=1))[0][0])
print(np.where(r.read_field(field_name='last_lambda', index=1)[10:])[0][0])
# Out:
# True None
# 621
# 288
# True None
# 621
# 275

# %%
plt.plot(r.read_field(field_name='lambda', index=1)[10:288])
# Out:
# 0.041070987 None
# 621
